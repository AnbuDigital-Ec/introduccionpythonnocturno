# %% [markdown]
# Escribir un programa en Python que pregute al usuario la edad por teclado y muestre en pantalla si es mayor de edad o no. Es mayor de edad cuando la edad es mayor o igual a 18

# %% [markdown]
# Escribir un p en py donde el usuario ingrese 2 números por teclado y muestre por pantalla la división de los dos números. Si el divisor es cero, el programa debe mostrsr el mensaje "No se puede dividir un valor para cero".

# %% [markdown]
# Escribir un p en py que pida al usaurio un numero por teclado y muestre en pantalla si el numero es par o impar.
#
# deber para el jueves
